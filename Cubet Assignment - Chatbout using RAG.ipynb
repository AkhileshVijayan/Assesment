# %% [markdown]
# # Problem statement
#
# Need to create a chatbout using GenAI.
#
# Steps of Assignment
# 1. Create a RAG based chatbot using any open source models(LLaMa2, LLaMa3, Mistral
# etc.)
# 2. Query from multiple documents
# 3. Improve the performance of Retrieval(control what goes to the LLM model)
# 4. You should use the documents that are shared with you with this email.
# Note: The query should be asked from multiple sources in a single query.
# For example, if there are 5 documents, the query can be ‘who prepared all the documents’

# %% [markdown]
# # Approach to the problem
#
#  Retrival Augmented Generation is a popular technology now days for chatbot to get the relevant information reagarding the query that the use ask. Sometimes, the information that we get is valid but not always!!.. This is a drawback in the RAG system and there is a lot of limitations when it comes to retrive or query among multiple documents.
#
# This notebook includes the simple RAG system and the Advanced RAG which I used to over the issue that I faced whilst creating a chatbout with RAG with multiple documents. There is more ways that we can solve the issue of retrieving the relevant chunks or piece of document but I just tried with only AGentic RAG.
#
# ### Approach 1 - Simple RAG system
#
#  Simple RAG system which works for single document but implement the same approach for multiple documents to get an idea of how it works and what all are the improvements it required.
#
# ### Approach 2 - Agentic RAG system
#
# This apporach will overcome the issue of retrieving or extracting the relevant information from the database as per the user query so that the users would be to get the informations from all documents as per the query. For example, if there are 5 documents, the query can be ‘who prepared all the documents’ then it will provide the names of the authors who prepared the documents.

# %% [markdown]
# ## Approach 1 - Simple RAG system
# Tech stack used  -  Langchain, FAISS(VectorDB), Open source LLMS (mistral , llama2)

# %%
# # #Install requirements
# !pip install sentence-transformers
# !pip install langchain
# !pip install langchain_community
# !pip install pypdf
# !pip install langchain_ollama
# !pip install -qU langchain-openai
# !pip install langchain-huggingface
# !pip install faiss-cpu
# Out:
# Requirement already satisfied: langchain in ./jupenv/lib/python3.9/site-packages (0.2.3)
# Requirement already satisfied: tenacity<9.0.0,>=8.1.0 in ./jupenv/lib/python3.9/site-packages (from langchain) (8.5.0)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in ./jupenv/lib/python3.9/site-packages (from langchain) (3.10.1)
# Requirement already satisfied: langchain-text-splitters<0.3.0,>=0.2.0 in ./jupenv/lib/python3.9/site-packages (from langchain) (0.2.2)
# Requirement already satisfied: requests<3,>=2 in ./jupenv/lib/python3.9/site-packages (from langchain) (2.32.3)
# Requirement already satisfied: async-timeout<5.0.0,>=4.0.0; python_version < "3.11" in ./jupenv/lib/python3.9/site-packages (from langchain) (4.0.3)
# Requirement already satisfied: langsmith<0.2.0,>=0.1.17 in ./jupenv/lib/python3.9/site-packages (from langchain) (0.1.98)
# Requirement already satisfied: pydantic<3,>=1 in ./jupenv/lib/python3.9/site-packages (from langchain) (2.8.2)
# Requirement already satisfied: numpy<2,>=1 in ./jupenv/lib/python3.9/site-packages (from langchain) (1.26.4)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in ./jupenv/lib/python3.9/site-packages (from langchain) (2.0.32)
# Requirement already satisfied: langchain-core<0.3.0,>=0.2.0 in ./jupenv/lib/python3.9/site-packages (from langchain) (0.2.28)
# Requirement already satisfied: PyYAML>=5.3 in ./jupenv/lib/python3.9/site-packages (from langchain) (6.0.2)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in ./jupenv/lib/python3.9/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (2.3.4)
# Requirement already satisfied: yarl<2.0,>=1.0 in ./jupenv/lib/python3.9/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (1.9.4)
# Requirement already satisfied: aiosignal>=1.1.2 in ./jupenv/lib/python3.9/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (1.3.1)
# Requirement already satisfied: frozenlist>=1.1.1 in ./jupenv/lib/python3.9/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in ./jupenv/lib/python3.9/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (6.0.5)
# Requirement already satisfied: attrs>=17.3.0 in ./jupenv/lib/python3.9/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (24.2.0)
# Requirement already satisfied: certifi>=2017.4.17 in ./jupenv/lib/python3.9/site-packages (from requests<3,>=2->langchain) (2024.7.4)
# Requirement already satisfied: charset-normalizer<4,>=2 in ./jupenv/lib/python3.9/site-packages (from requests<3,>=2->langchain) (3.3.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in ./jupenv/lib/python3.9/site-packages (from requests<3,>=2->langchain) (2.2.2)
# Requirement already satisfied: idna<4,>=2.5 in ./jupenv/lib/python3.9/site-packages (from requests<3,>=2->langchain) (3.7)
# Requirement already satisfied: orjson<4.0.0,>=3.9.14 in ./jupenv/lib/python3.9/site-packages (from langsmith<0.2.0,>=0.1.17->langchain) (3.10.6)
# Requirement already satisfied: typing-extensions>=4.6.1; python_version < "3.13" in ./jupenv/lib/python3.9/site-packages (from pydantic<3,>=1->langchain) (4.12.2)
# Requirement already satisfied: pydantic-core==2.20.1 in ./jupenv/lib/python3.9/site-packages (from pydantic<3,>=1->langchain) (2.20.1)
# Requirement already satisfied: annotated-types>=0.4.0 in ./jupenv/lib/python3.9/site-packages (from pydantic<3,>=1->langchain) (0.7.0)
# Requirement already satisfied: greenlet!=0.4.17; python_version < "3.13" and (platform_machine == "aarch64" or (platform_machine == "ppc64le" or (platform_machine == "x86_64" or (platform_machine == "amd64" or (platform_machine == "AMD64" or (platform_machine == "win32" or platform_machine == "WIN32")))))) in ./jupenv/lib/python3.9/site-packages (from SQLAlchemy<3,>=1.4->langchain) (3.0.3)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in ./jupenv/lib/python3.9/site-packages (from langchain-core<0.3.0,>=0.2.0->langchain) (1.33)
# Requirement already satisfied: packaging<25,>=23.2 in ./jupenv/lib/python3.9/site-packages (from langchain-core<0.3.0,>=0.2.0->langchain) (24.1)
# Requirement already satisfied: jsonpointer>=1.9 in ./jupenv/lib/python3.9/site-packages (from jsonpatch<2.0,>=1.33->langchain-core<0.3.0,>=0.2.0->langchain) (3.0.0)
# Requirement already satisfied: langchain_community in ./jupenv/lib/python3.9/site-packages (0.2.4)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in ./jupenv/lib/python3.9/site-packages (from langchain_community) (2.0.32)
# Requirement already satisfied: dataclasses-json<0.7,>=0.5.7 in ./jupenv/lib/python3.9/site-packages (from langchain_community) (0.6.7)
# Requirement already satisfied: langsmith<0.2.0,>=0.1.0 in ./jupenv/lib/python3.9/site-packages (from langchain_community) (0.1.98)
# Requirement already satisfied: tenacity<9.0.0,>=8.1.0 in ./jupenv/lib/python3.9/site-packages (from langchain_community) (8.5.0)
# Requirement already satisfied: numpy<2,>=1 in ./jupenv/lib/python3.9/site-packages (from langchain_community) (1.26.4)
# Requirement already satisfied: langchain-core<0.3.0,>=0.2.0 in ./jupenv/lib/python3.9/site-packages (from langchain_community) (0.2.28)
# Requirement already satisfied: PyYAML>=5.3 in ./jupenv/lib/python3.9/site-packages (from langchain_community) (6.0.2)
# Requirement already satisfied: requests<3,>=2 in ./jupenv/lib/python3.9/site-packages (from langchain_community) (2.32.3)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in ./jupenv/lib/python3.9/site-packages (from langchain_community) (3.10.1)
# Requirement already satisfied: langchain<0.3.0,>=0.2.0 in ./jupenv/lib/python3.9/site-packages (from langchain_community) (0.2.3)
# Requirement already satisfied: typing-extensions>=4.6.0 in ./jupenv/lib/python3.9/site-packages (from SQLAlchemy<3,>=1.4->langchain_community) (4.12.2)
# Requirement already satisfied: greenlet!=0.4.17; python_version < "3.13" and (platform_machine == "aarch64" or (platform_machine == "ppc64le" or (platform_machine == "x86_64" or (platform_machine == "amd64" or (platform_machine == "AMD64" or (platform_machine == "win32" or platform_machine == "WIN32")))))) in ./jupenv/lib/python3.9/site-packages (from SQLAlchemy<3,>=1.4->langchain_community) (3.0.3)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in ./jupenv/lib/python3.9/site-packages (from dataclasses-json<0.7,>=0.5.7->langchain_community) (3.21.3)
# Requirement already satisfied: typing-inspect<1,>=0.4.0 in ./jupenv/lib/python3.9/site-packages (from dataclasses-json<0.7,>=0.5.7->langchain_community) (0.9.0)
# Requirement already satisfied: orjson<4.0.0,>=3.9.14 in ./jupenv/lib/python3.9/site-packages (from langsmith<0.2.0,>=0.1.0->langchain_community) (3.10.6)
# Requirement already satisfied: pydantic<3,>=1; python_full_version < "3.12.4" in ./jupenv/lib/python3.9/site-packages (from langsmith<0.2.0,>=0.1.0->langchain_community) (2.8.2)
# Requirement already satisfied: packaging<25,>=23.2 in ./jupenv/lib/python3.9/site-packages (from langchain-core<0.3.0,>=0.2.0->langchain_community) (24.1)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in ./jupenv/lib/python3.9/site-packages (from langchain-core<0.3.0,>=0.2.0->langchain_community) (1.33)
# Requirement already satisfied: idna<4,>=2.5 in ./jupenv/lib/python3.9/site-packages (from requests<3,>=2->langchain_community) (3.7)
# Requirement already satisfied: certifi>=2017.4.17 in ./jupenv/lib/python3.9/site-packages (from requests<3,>=2->langchain_community) (2024.7.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in ./jupenv/lib/python3.9/site-packages (from requests<3,>=2->langchain_community) (2.2.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in ./jupenv/lib/python3.9/site-packages (from requests<3,>=2->langchain_community) (3.3.2)
# Requirement already satisfied: async-timeout<5.0,>=4.0; python_version < "3.11" in ./jupenv/lib/python3.9/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community) (4.0.3)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in ./jupenv/lib/python3.9/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community) (2.3.4)
# Requirement already satisfied: aiosignal>=1.1.2 in ./jupenv/lib/python3.9/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community) (1.3.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in ./jupenv/lib/python3.9/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community) (6.0.5)
# Requirement already satisfied: yarl<2.0,>=1.0 in ./jupenv/lib/python3.9/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community) (1.9.4)
# Requirement already satisfied: frozenlist>=1.1.1 in ./jupenv/lib/python3.9/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community) (1.4.1)
# Requirement already satisfied: attrs>=17.3.0 in ./jupenv/lib/python3.9/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community) (24.2.0)
# Requirement already satisfied: langchain-text-splitters<0.3.0,>=0.2.0 in ./jupenv/lib/python3.9/site-packages (from langchain<0.3.0,>=0.2.0->langchain_community) (0.2.2)
# Requirement already satisfied: mypy-extensions>=0.3.0 in ./jupenv/lib/python3.9/site-packages (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7,>=0.5.7->langchain_community) (1.0.0)
# Requirement already satisfied: annotated-types>=0.4.0 in ./jupenv/lib/python3.9/site-packages (from pydantic<3,>=1; python_full_version < "3.12.4"->langsmith<0.2.0,>=0.1.0->langchain_community) (0.7.0)
# Requirement already satisfied: pydantic-core==2.20.1 in ./jupenv/lib/python3.9/site-packages (from pydantic<3,>=1; python_full_version < "3.12.4"->langsmith<0.2.0,>=0.1.0->langchain_community) (2.20.1)
# Requirement already satisfied: jsonpointer>=1.9 in ./jupenv/lib/python3.9/site-packages (from jsonpatch<2.0,>=1.33->langchain-core<0.3.0,>=0.2.0->langchain_community) (3.0.0)
# Requirement already satisfied: pypdf in ./jupenv/lib/python3.9/site-packages (4.3.1)
# Requirement already satisfied: typing_extensions>=4.0; python_version < "3.11" in ./jupenv/lib/python3.9/site-packages (from pypdf) (4.12.2)
# Requirement already satisfied: langchain_ollama in ./jupenv/lib/python3.9/site-packages (0.1.1)
# Requirement already satisfied: langchain-core<0.3.0,>=0.2.20 in ./jupenv/lib/python3.9/site-packages (from langchain_ollama) (0.2.28)
# Requirement already satisfied: ollama<1,>=0.3.0 in ./jupenv/lib/python3.9/site-packages (from langchain_ollama) (0.3.1)
# Requirement already satisfied: tenacity!=8.4.0,<9.0.0,>=8.1.0 in ./jupenv/lib/python3.9/site-packages (from langchain-core<0.3.0,>=0.2.20->langchain_ollama) (8.5.0)
# Requirement already satisfied: PyYAML>=5.3 in ./jupenv/lib/python3.9/site-packages (from langchain-core<0.3.0,>=0.2.20->langchain_ollama) (6.0.2)
# Requirement already satisfied: langsmith<0.2.0,>=0.1.75 in ./jupenv/lib/python3.9/site-packages (from langchain-core<0.3.0,>=0.2.20->langchain_ollama) (0.1.98)
# Requirement already satisfied: packaging<25,>=23.2 in ./jupenv/lib/python3.9/site-packages (from langchain-core<0.3.0,>=0.2.20->langchain_ollama) (24.1)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in ./jupenv/lib/python3.9/site-packages (from langchain-core<0.3.0,>=0.2.20->langchain_ollama) (1.33)
# Requirement already satisfied: typing-extensions>=4.7 in ./jupenv/lib/python3.9/site-packages (from langchain-core<0.3.0,>=0.2.20->langchain_ollama) (4.12.2)
# Requirement already satisfied: pydantic<3,>=1; python_full_version < "3.12.4" in ./jupenv/lib/python3.9/site-packages (from langchain-core<0.3.0,>=0.2.20->langchain_ollama) (2.8.2)
# Requirement already satisfied: httpx<0.28.0,>=0.27.0 in ./jupenv/lib/python3.9/site-packages (from ollama<1,>=0.3.0->langchain_ollama) (0.27.0)
# Requirement already satisfied: requests<3,>=2 in ./jupenv/lib/python3.9/site-packages (from langsmith<0.2.0,>=0.1.75->langchain-core<0.3.0,>=0.2.20->langchain_ollama) (2.32.3)
# Requirement already satisfied: orjson<4.0.0,>=3.9.14 in ./jupenv/lib/python3.9/site-packages (from langsmith<0.2.0,>=0.1.75->langchain-core<0.3.0,>=0.2.20->langchain_ollama) (3.10.6)
# Requirement already satisfied: jsonpointer>=1.9 in ./jupenv/lib/python3.9/site-packages (from jsonpatch<2.0,>=1.33->langchain-core<0.3.0,>=0.2.20->langchain_ollama) (3.0.0)
# Requirement already satisfied: pydantic-core==2.20.1 in ./jupenv/lib/python3.9/site-packages (from pydantic<3,>=1; python_full_version < "3.12.4"->langchain-core<0.3.0,>=0.2.20->langchain_ollama) (2.20.1)
# Requirement already satisfied: annotated-types>=0.4.0 in ./jupenv/lib/python3.9/site-packages (from pydantic<3,>=1; python_full_version < "3.12.4"->langchain-core<0.3.0,>=0.2.20->langchain_ollama) (0.7.0)
# Requirement already satisfied: certifi in ./jupenv/lib/python3.9/site-packages (from httpx<0.28.0,>=0.27.0->ollama<1,>=0.3.0->langchain_ollama) (2024.7.4)
# Requirement already satisfied: idna in ./jupenv/lib/python3.9/site-packages (from httpx<0.28.0,>=0.27.0->ollama<1,>=0.3.0->langchain_ollama) (3.7)
# Requirement already satisfied: sniffio in ./jupenv/lib/python3.9/site-packages (from httpx<0.28.0,>=0.27.0->ollama<1,>=0.3.0->langchain_ollama) (1.3.1)
# Requirement already satisfied: anyio in ./jupenv/lib/python3.9/site-packages (from httpx<0.28.0,>=0.27.0->ollama<1,>=0.3.0->langchain_ollama) (4.4.0)
# Requirement already satisfied: httpcore==1.* in ./jupenv/lib/python3.9/site-packages (from httpx<0.28.0,>=0.27.0->ollama<1,>=0.3.0->langchain_ollama) (1.0.5)
# Requirement already satisfied: charset-normalizer<4,>=2 in ./jupenv/lib/python3.9/site-packages (from requests<3,>=2->langsmith<0.2.0,>=0.1.75->langchain-core<0.3.0,>=0.2.20->langchain_ollama) (3.3.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in ./jupenv/lib/python3.9/site-packages (from requests<3,>=2->langsmith<0.2.0,>=0.1.75->langchain-core<0.3.0,>=0.2.20->langchain_ollama) (2.2.2)
# Requirement already satisfied: exceptiongroup>=1.0.2; python_version < "3.11" in ./jupenv/lib/python3.9/site-packages (from anyio->httpx<0.28.0,>=0.27.0->ollama<1,>=0.3.0->langchain_ollama) (1.2.2)
# Requirement already satisfied: h11<0.15,>=0.13 in ./jupenv/lib/python3.9/site-packages (from httpcore==1.*->httpx<0.28.0,>=0.27.0->ollama<1,>=0.3.0->langchain_ollama) (0.14.0)
# Requirement already satisfied: faiss-cpu in ./jupenv/lib/python3.9/site-packages (1.8.0)
# Requirement already satisfied: numpy in ./jupenv/lib/python3.9/site-packages (from faiss-cpu) (1.26.4)

# %%
# !pip install langchain-community==0.2.4 langchain==0.2.3 faiss-cpu==1.8.0 transformers==4.41.2 sentence-transformers==3.0.1

# %%
import os
from langchain_community.llms import Ollama
from langchain_community.document_loaders import PyPDFLoader
from langchain_community.vectorstores import FAISS
from langchain.embeddings import HuggingFaceEmbeddings
from langchain.text_splitter import RecursiveCharacterTextSplitter
from langchain.chains import RetrievalQA
from langchain_openai import ChatOpenAI
from langchain_openai import OpenAIEmbeddings
from langchain_ollama import OllamaEmbeddings

# %% [markdown]
# #### Link to install ollama and download the model locally
# https://ollama.com/

# %%
# !ollama list
# Out:
# NAME                   	ID          	SIZE  	MODIFIED
# mistral:latest         	f974a74358d6	4.1 GB	7 hours ago
# nomic-embed-text:latest	0a109f422b47	274 MB	8 hours ago
# llama2:latest          	78e26419b446	3.8 GB	19 hours ago
# llama3.1:8b            	62757c860e01	4.7 GB	23 hours ago

# %% [markdown]
# #### If you are trying with Openai please provide the openai key here

# %%
OPENAI_API_KEY = "openi_ai_key"

# %%
# loading the  llama3 LLM
llm = Ollama(
    model="llama3.1:8b",
    temperature=0
)

#openai llm
# llm = ChatOpenAI(
#     model="gpt-4o-mini",
#     temperature=0,
#     max_tokens=None,
#     timeout=None,
#     max_retries=2,
#     openai_api_key = OPENAI_API_KEY )

# %% [markdown]
# ### We can either use any pdf loaders or even unstructured document loaders for all docs or pdf

# %%
# pdf_path = "cubet_pdfs"
# def load_documents():
#     document_loader = PyPDFDirectoryLoader(pdf_path)
#     return document_loader.load()
# documents = load_documents()

# %%
# len(documents)

# %%
# documents[:3]

# %%
#Here I'm using the PyPDFLoader as document loader and recursivecharactersplitter to split the documents to chunk_size mentioned in code.
def load_and_process_pdfs(pdf_folder_path):
    documents = []
    for file in os.listdir(pdf_folder_path):
        if file.endswith('.pdf'):
            pdf_path = os.path.join(pdf_folder_path, file)
            loader = PyPDFLoader(pdf_path)
            documents.extend(loader.load())
    text_splitter = RecursiveCharacterTextSplitter(chunk_size=1024, chunk_overlap=200)
    splits = text_splitter.split_documents(documents)
    return splits
pdf_path = "cubet_pdfs"
splitted_docs = load_and_process_pdfs(pdf_path)
splitted_docs[:3]
# Out:
# [Document(metadata={'source': 'cubet_pdfs/SRS_ Tekdoc.pdf', 'page': 0}, page_content='Software\nRequirement\nSpeciﬁcation\nFor\nTekdoc\nSoftware\nVersion:\n1.0 \nAnnexure\nA\nPrepared\nby:\nKrishnapriya\nCubet\nTechno\nLabs\nPVT\nLTD\n03-June-2020'),
#  Document(metadata={'source': 'cubet_pdfs/SRS_ Tekdoc.pdf', 'page': 1}, page_content='Table\nof\nContents\n1.\nIntroduction\n1.1\nPurpose\n1.2\nScope\n1.3\nIntended\nAudience\nand\nReading\nSuggestions\n1.4\nTerms\nand\nAbbreviations\n1.5\nBeneﬁciaries\n2.\nOverAll\nDescription\n2.1\nProduct\nPerspective\n2.2\nUser\nRoles\n2.3\nDataFlow\nDiagram\n2.4\nUseCase\nDiagram\n2.5\nUserFlow\nof\nMobile\nApp\n2.6\nUser\nStories\n2.7\nFlowchart\n3.\nSystem\nRequirements\n3.1\nFunctional\nRequirements\n3.2\nUX/UI\nBreakdown\n3.3\nNon\nFunctional\nRequirements\n4.\nUpdated\nfeatures\nof\nTekdoc-Phase2\n5.\nAssumptions'),
#  Document(metadata={'source': 'cubet_pdfs/SRS_ Tekdoc.pdf', 'page': 2}, page_content='Revision\nHistory\nV er sionAuthorDa t eCommen ts\n1.0.0\n●K rishnapriy aJune2020Theinitialdr a ft.\n1.0.1\n●K rishnapriy a22Mar ch2021R equir emen tsf orPhase2\n1.AdditionofUserR oles-Nur se,R ecep tionis ts.\n2.Dashboar dsf orNur sesandR ecep tionis ts.\n3.Chr onologic alHis t or ydispla y\na.AdditionofSO APNot edispla y .\nb.Car dvie wofP a tien tCharts.\nc.Atimelinevie wofMedic alDiagnosis')]

# %%
#If you want to use openaiembediings, please uncomment the last one and comment the first embeddings variable
embeddings = OllamaEmbeddings(model="nomic-embed-text:latest")
# embeddings = OpenAIEmbeddings(model="text-embedding-ada-002", api_key=OPENAI_API_KEY)

# %%
#example embeddings
embeddings.embed_query("Hi, demo for cubet")
# Out:
# [-0.00096889003,
#  0.022380479,
#  -0.15100619,
#  -0.01760835,
#  0.038781606,
#  0.022319948,
#  0.010763753,
#  -0.021621116,
#  -0.06810876,
#  -0.0106204515,
#  -0.022100618,
#  0.08592628,
#  0.068449125,
#  0.046536922,
#  -0.05160825,
#  -0.0066468976,
#  -0.0002869543,
#  -0.048650928,
#  0.02700468,
#  0.102889605,
#  0.052824352,
#  -0.061270118,
#  -0.049036395,
#  -0.057935316,
#  0.08107898,
#  0.03811832,
#  0.04749662,
#  0.057555817,
#  -0.021150468,
#  0.035806693,
#  0.08614739,
#  -0.07682749,
#  -0.0066961786,
#  -0.00030020074,
#  -0.0076031927,
#  -0.01549189,
#  0.054195885,
#  -0.004978864,
#  -0.038154505,
#  -0.025034217,
#  0.0070408992,
#  -0.009442246,
#  -0.019315613,
#  -0.042764932,
#  0.009057923,
#  0.03627235,
#  0.06544575,
#  0.04575138,
#  -0.04231415,
#  0.0051195077,
#  0.018508025,
#  -0.009357308,
#  0.041531675,
#  -0.034146283,
#  0.010708779,
#  -0.03030304,
#  -0.01206765,
#  -0.003058584,
#  -0.018136319,
#  -0.04229225,
#  0.024378259,
#  0.057572804,
#  -0.019227948,
#  0.06876179,
#  0.06895448,
#  -0.0090079345,
#  0.023904905,
#  0.030311266,
#  -0.00094508805,
#  -0.016635258,
#  -0.00084475154,
#  0.01898198,
#  0.046351068,
#  0.025289048,
#  -0.030526217,
#  -0.021896785,
#  -0.018027946,
#  -0.03747677,
#  -0.037782546,
#  0.02195048,
#  0.012173994,
#  -0.0038710178,
#  0.034826368,
#  -0.02362862,
#  0.035062414,
#  -0.04547537,
#  0.008063287,
#  -0.002815099,
#  -0.023812888,
#  0.08127674,
#  0.0101889735,
#  0.043821704,
#  0.021138877,
#  0.010406847,
#  -0.04852646,
#  -0.013793277,
#  -0.01728729,
#  0.008330762,
#  -0.004821875,
#  0.00795128,
#  -0.018905472,
#  -0.043782573,
#  -0.013059263,
#  -0.016377142,
#  0.032589987,
#  0.05338152,
#  -0.030638658,
#  -0.013473522,
#  -0.008141708,
#  0.0241764,
#  -0.007250533,
#  -0.03165332,
#  -0.030786728,
#  0.017781857,
#  0.029934973,
#  -0.010907624,
#  0.059420623,
#  -0.07629928,
#  -0.03961079,
#  0.008355013,
#  -0.014392103,
#  0.006863797,
#  0.01715104,
#  0.029888116,
#  0.042536568,
#  0.105034515,
#  -0.031406745,
#  -0.029590383,
#  -0.018618021,
#  -0.0076226094,
#  -0.011752692,
#  -0.002914627,
#  -0.039302696,
#  -0.04216263,
#  0.0067301113,
#  0.05710889,
#  -0.05337424,
#  0.025369447,
#  0.013501263,
#  -0.011361246,
#  -0.0029081157,
#  0.022242442,
#  -0.0031773208,
#  0.020498507,
#  -0.014400235,
#  -0.048347656,
#  0.060976304,
#  -0.011582354,
#  -0.049885668,
#  -0.01526622,
#  0.010986563,
#  0.0031186831,
#  0.012293874,
#  0.019490628,
#  0.024080552,
#  -0.0076777106,
#  0.017781194,
#  0.0032616067,
#  0.019864498,
#  -0.010208875,
#  -0.006141223,
#  -0.027132563,
#  -0.040187873,
#  0.016308079,
#  -0.047722775,
#  -0.042554893,
#  0.050360896,
#  0.044087403,
#  0.061384518,
#  0.03392804,
#  -0.065953195,
#  -0.013508221,
#  0.00884991,
#  0.059792705,
#  -0.023779113,
#  -0.021504737,
#  -0.025257925,
#  -0.02192886,
#  0.013287545,
#  -0.08255933,
#  0.027247231,
#  -0.03338191,
#  0.026537407,
#  0.04999607,
#  -0.035767663,
#  -0.029384052,
#  0.06934105,
#  -0.017831106,
#  0.0057278248,
#  0.017567012,
#  0.035009895,
#  -0.0012883381,
#  -0.11354416,
#  -0.01482442,
#  -0.0027490475,
#  -0.047908373,
#  0.09716173,
#  0.03517305,
#  0.011945025,
#  -0.03257437,
#  0.009934071,
#  -0.0009773691,
#  0.05286061,
#  0.040247653,
#  -0.03710678,
#  0.015527067,
#  -0.0019487233,
#  -0.016357524,
#  0.014346597,
#  0.013588477,
#  0.054508444,
#  -0.0069810357,
#  -0.042260982,
#  -0.006145728,
#  0.006149157,
#  -0.013107058,
#  0.044034675,
#  -0.073491804,
#  -0.023894386,
#  0.0024781711,
#  -0.0033886973,
#  -0.014191219,
#  -0.022556914,
#  -0.022304296,
#  0.042080306,
#  -0.026014328,
#  -0.02272381,
#  0.016520076,
#  -0.012253666,
#  0.021675095,
#  -0.029834334,
#  -0.05214434,
#  0.005748236,
#  0.025021646,
#  0.020516552,
#  0.049676344,
#  -0.040594306,
#  0.048148327,
#  -0.03083049,
#  -0.020261005,
#  0.0032236187,
#  0.026434738,
#  0.008229046,
#  -0.033280868,
#  -0.06398931,
#  -0.037868485,
#  0.0053175604,
#  -0.00852351,
#  0.0657205,
#  0.022588663,
#  -0.017705113,
#  0.021433044,
#  0.006914031,
#  0.016149942,
#  0.034012336,
#  0.035300285,
#  -0.012960259,
#  -0.010745523,
#  -0.015926251,
#  -0.039042182,
#  0.0043918653,
#  -0.010765268,
#  0.0060532256,
#  -0.0016754235,
#  0.018684248,
#  -0.017796887,
#  -0.017047867,
#  -0.015883159,
#  0.011097998,
#  -0.020462884,
#  0.011743585,
#  0.040755317,
#  -0.010065829,
#  3.1524692e-06,
#  -0.021184498,
#  0.011407351,
#  0.031375837,
#  0.04253277,
#  -0.018261857,
#  0.015285914,
#  -0.044188,
#  -0.03348118,
#  -0.032219484,
#  -0.0002090507,
#  -0.03146874,
#  0.036587987,
#  -0.01014353,
#  -0.043283883,
#  0.013724134,
#  0.027696302,
#  0.015245965,
#  -0.032223232,
#  0.0010639126,
#  0.036735866,
#  -0.02163874,
#  -0.04552515,
#  0.002726731,
#  0.0130957225,
#  -0.0035004045,
#  -0.0054838685,
#  0.00044639866,
#  0.031726036,
#  0.113959126,
#  -0.023727192,
#  -0.004129456,
#  -0.06888352,
#  0.053286877,
#  -0.042721864,
#  0.04177249,
#  -0.018781299,
#  -0.026203388,
#  0.02263801,
#  -0.106079206,
#  0.022327187,
#  -0.055134907,
#  0.022346318,
#  0.030711375,
#  0.029466875,
#  0.082734555,
#  -0.00172099,
#  0.06350925,
#  -0.018077627,
#  0.010051906,
#  -0.024950575,
#  -0.0023171988,
#  0.029353589,
#  0.03808548,
#  0.026571862,
#  0.07984491,
#  -0.027894648,
#  0.039957225,
#  0.03733283,
#  -0.046647426,
#  -0.0071497755,
#  -0.04098735,
#  0.033704083,
#  -0.015437314,
#  -0.013785913,
#  -0.0024936378,
#  0.060344007,
#  0.02794666,
#  0.029877122,
#  -0.05530101,
#  -0.035578378,
#  -0.03059803,
#  -0.063189894,
#  -0.013265559,
#  0.019747417,
#  0.0032222108,
#  0.036157764,
#  -0.014807598,
#  -0.028779984,
#  0.036998857,
#  0.0056526246,
#  0.0061651166,
#  -0.016387958,
#  0.05423731,
#  0.027768694,
#  -0.01146554,
#  -0.008763416,
#  0.044129442,
#  0.021015182,
#  0.055808607,
#  0.0022103537,
#  -0.030621124,
#  0.019471457,
#  0.046832807,
#  0.047940005,
#  0.0003694394,
#  0.0019306659,
#  -0.025749484,
#  -0.08653806,
#  0.02280874,
#  0.050539184,
#  0.052975934,
#  -0.038074,
#  -0.059703436,
#  -0.050468642,
#  -0.010858821,
#  0.01742741,
#  0.033264805,
#  -0.058449216,
#  0.05131294,
#  -0.03356097,
#  0.036398843,
#  -0.01031496,
#  0.08042037,
#  0.019418767,
#  -0.0041953553,
#  -0.017239945,
#  -0.0072419206,
#  -0.0424742,
#  -0.026059058,
#  0.038648985,
#  -0.017442506,
#  0.028850758,
#  0.055576976,
#  -0.0053100716,
#  -0.07454811,
#  0.010698898,
#  -0.047166634,
#  -0.042930268,
#  -0.020662602,
#  -0.0909143,
#  0.029324144,
#  -0.013848216,
#  -0.067519605,
#  -0.050874002,
#  0.049248464,
#  -0.028861824,
#  0.031776633,
#  -0.02548518,
#  0.004039727,
#  -0.042962056,
#  0.00851392,
#  -0.016358536,
#  0.018887414,
#  0.0035170245,
#  0.008981775,
#  -0.0016763859,
#  0.08481448,
#  0.0726114,
#  -0.014609511,
#  0.004615514,
#  -0.00686161,
#  0.023575045,
#  0.036804244,
#  0.044403974,
#  -0.010194884,
#  -0.04177754,
#  0.021039404,
#  -0.006022945,
#  0.037335645,
#  0.019713128,
#  -0.00587058,
#  -0.016597401,
#  0.04009057,
#  -0.00069523184,
#  -0.0153766405,
#  0.012229668,
#  0.02203424,
#  -0.0144981975,
#  0.011833207,
#  -0.08782539,
#  -0.0016706713,
#  0.09910692,
#  0.062382698,
#  -0.061057474,
#  -0.034985714,
#  0.03829652,
#  0.052189905,
#  -0.051117208,
#  0.0064947857,
#  0.067809604,
#  0.03652427,
#  -0.016168397,
#  0.071836226,
#  -0.025739875,
#  0.009262322,
#  0.022664767,
#  -0.028111383,
#  0.0077934354,
#  -0.0139312865,
#  0.00797563,
#  -2.5589588e-05,
#  -0.008526018,
#  -0.03324782,
#  0.002259981,
#  0.031440396,
#  0.035800196,
#  -0.028828934,
#  -0.012360092,
#  0.045397677,
#  0.03073911,
#  -0.018464679,
#  -0.0008627758,
#  -0.021148227,
#  -0.012914253,
#  0.004732477,
#  0.023658713,
#  0.050644226,
#  0.0072517553,
#  -0.04880802,
#  -0.04819347,
#  0.05274099,
#  0.06132786,
#  0.04520907,
#  0.015756765,
#  -0.00068423524,
#  -0.013267117,
#  0.03374205,
#  0.025190406,
#  0.021638125,
#  0.0047783605,
#  -0.029241893,
#  -0.0040089283,
#  -0.040563315,
#  0.0011856651,
#  0.028648393,
#  -0.007910126,
#  0.03597369,
#  -0.0012320259,
#  -0.0141425785,
#  0.019555885,
#  -0.0013353179,
#  -0.01118688,
#  0.024192583,
#  -0.03573586,
#  -0.06156693,
#  0.021754896,
#  -0.05276143,
#  0.041838873,
#  0.03609596,
#  0.027172359,
#  0.03095427,
#  -0.022070477,
#  -0.005735669,
#  -0.032711897,
#  -0.040858723,
#  0.02583158,
#  -0.012825794,
#  -0.037304066,
#  0.031302433,
#  -0.019030616,
#  -0.0055758706,
#  0.031000279,
#  -0.0042151306,
#  0.0008121188,
#  0.019212216,
#  -0.035704907,
#  -0.04523859,
#  0.028785132,
#  -0.01654182,
#  -0.038219094,
#  -0.06360931,
#  -0.011829428,
#  -0.006033507,
#  0.0064057424,
#  0.02283035,
#  0.007196642,
#  -0.04933698,
#  0.021596534,
#  -0.019387843,
#  0.015218625,
#  0.0059860284,
#  -0.0022259108,
#  -0.042620998,
#  0.05511655,
#  0.0138225285,
#  -0.0316698,
#  0.02350599,
#  -0.026679173,
#  -0.0019809161,
#  -0.014354031,
#  0.038760386,
#  -0.063096724,
#  -0.004312973,
#  -0.047318436,
#  -0.043102466,
#  -0.030344632,
#  0.028697025,
#  0.007889485,
#  0.07875567,
#  -0.0046431874,
#  -0.008336893,
#  -0.013037897,
#  0.044584822,
#  0.025887657,
#  0.026466334,
#  0.024712278,
#  -0.029101914,
#  -0.076526225,
#  -0.0031970511,
#  -0.008982852,
#  -0.022355225,
#  0.007211107,
#  0.016955983,
#  0.010337108,
#  -0.048270725,
#  0.00984182,
#  -0.026773836,
#  -0.07116888,
#  -0.010167192,
#  0.06321578,
#  0.019885022,
#  0.022547835,
#  -0.007823495,
#  -0.10621497,
#  -0.020324185,
#  -0.036270503,
#  -0.0507976,
#  -0.015971636,
#  0.051889565,
#  -0.019652061,
#  0.005662159,
#  0.00268482,
#  -0.053562548,
#  -0.04844612,
#  -0.0061148833,
#  0.0009325809,
#  -0.011021473,
#  0.029015882,
#  -0.00045875975,
#  -0.08346748,
#  -0.048778046,
#  0.043031,
#  0.01064355,
#  -0.026890205,
#  0.049393937,
#  -0.031442128,
#  0.072938666,
#  0.02657,
#  -0.044834863,
#  -0.020956416,
#  0.032638267,
#  -0.0046095573,
#  0.042362787,
#  -0.03536475,
#  0.0016001033,
#  -0.035266202,
#  0.034734342,
#  -0.003189365,
#  0.014193892,
#  -0.06024145,
#  0.018746005,
#  0.0038397573,
#  -0.02420731,
#  -0.03662049,
#  0.010032591,
#  0.0641378,
#  -0.003058625,
#  -0.014281261,
#  -0.048152644,
#  -0.012605164,
#  -0.031138165,
#  0.05711706,
#  0.010183716,
#  0.012767998,
#  0.040693242,
#  -0.00035745473,
#  0.034106877,
#  0.0038707103,
#  -0.012570869,
#  0.004942144,
#  0.022829566,
#  -0.022427194,
#  0.05617396,
#  0.044138547,
#  0.05117012,
#  -0.026594378,
#  0.021860255,
#  0.025007358,
#  0.018671773,
#  -0.058080517,
#  -0.022323636,
#  0.0114865005,
#  -0.0038013204,
#  -0.016679095,
#  -0.061464816,
#  -0.038542993,
#  -0.054328464,
#  0.014338109,
#  -0.06769235,
#  -0.005436702,
#  0.05381554,
#  -0.036428038,
#  -0.003941616,
#  0.012270272,
#  -0.06550431,
#  -0.044378612,
#  0.004641082,
#  0.052488893,
#  -0.022732046,
#  -4.335332e-05,
#  -0.033087105,
#  -0.012849956,
#  0.018470958,
#  0.05312534,
#  -0.010901632,
#  -0.02782672,
#  -0.019541299,
#  0.010221509,
#  0.017173665,
#  0.017315838,
#  0.03433819,
#  -0.049569063,
#  0.008464691,
#  0.026970958,
#  -0.057164013,
#  -0.057382252,
#  -0.02739769,
#  -0.03805529,
#  -0.0009357085,
#  -0.027058093,
#  -0.01954919,
#  0.0033285483,
#  0.005826484,
#  -0.025991475,
#  -0.020400003,
#  0.09907293,
#  -0.034234796,
#  0.001115141,
#  0.011784862,
#  0.013016393,
#  -0.066027634,
#  0.011902623,
#  0.009781871,
#  -0.0040594256,
#  -0.018251516,
#  0.0035091557,
#  0.0030855858,
#  0.034342263,
#  0.0070343073,
#  0.047171995,
#  -0.003126735,
#  0.07317831,
#  -0.042758185,
#  -0.0291145,
#  0.012701031,
#  0.014448202,
#  0.031376258,
#  0.0028529412,
#  -0.079747945,
#  -0.024515247,
#  0.041305758,
#  -0.06569635,
#  -0.02036103,
#  -0.006531201,
#  0.017340764,
#  -0.007077641,
#  0.027218338,
#  0.025937313,
#  -0.0083214305,
#  0.027534159,
#  -0.005257004,
#  0.035997905,
#  -0.0254336,
#  -0.0011913998,
#  0.01727217,
#  -0.026112372,
#  -0.05304623,
#  0.0275542,
#  -0.007174391,
#  0.05121492,
#  -0.0018698202,
#  0.017281989,
#  -0.056309756,
#  -0.031569522,
#  -0.0071313996,
#  0.0028826857,
#  0.07153504,
#  -0.0624292,
#  0.0044284374,
#  -0.026715863,
#  -0.024390476,
#  0.011526079,
#  -0.0026412134,
#  -0.0005305589,
#  0.11688349,
#  -0.012799839,
#  -0.0004772656,
#  -0.040770806,
#  0.093078,
#  0.03668428,
#  0.011423514,
#  0.013627721,
#  -0.0131934825,
#  0.0022264072]

# %%
knowledge_base = FAISS.from_documents(splitted_docs, embeddings)
# Out:
# KeyboardInterrupt

# %%
# retrieval QA chain
qa_chain = RetrievalQA.from_chain_type(
    llm,
    retriever=knowledge_base.as_retriever())

# %%
question = "Who all prepared the documents?"
retrieved_documents = knowledge_base.similarity_search(question,k=5)
retrieved_documents
# Out:
# [Document(metadata={'source': 'cubet_pdfs/SRS_ MyLeaseAudit.pdf', 'page': 32}, page_content='T h e\nd e l e t e\nb u t t o n\np r e s e n t\ni n\nt h e\nL o c a t i o n\nl i s t i n g\np a g e\ne n a b l e s\nu s e r s\nt o\nd e l e t e\nl o c a t i o n\na n d\ni t s\na s s o c i a t e d\nA u d i t s ,\nL e a s e s ,\nS t a t e m e n t s .\nF.\nASSIGN AUDITORS\n33'),
#  Document(metadata={'source': 'cubet_pdfs/OPD Booster-SRS V3.0.pdf', 'page': 88}, page_content='The\nfrontdesk\nuser\non\nclicking\nthe\nDocuments\ntab\nwill\nland\nat\nthe\nabove\npage.\nIt\nwill\nlist\nall\nthe\ndocuments\npertaining\nto\nthe\npatient.\nThe\ndocuments\nare\ncategorized\ninto\nDischarge\nSummary,\nBioChemical\nReport\nand\nGeneral.\nBiochemical\nreports\nwill\nhave\nthe\nreports\nfrom\nthe\nlaboratory\nuploaded\nby\nthe\ndoctors/patients.\nOPD\nBooster\n|\nConfidential\nCopyright\n©\n2024,\nCubet.\nAll\nrights\nreserved.\nPage\n89\nof\n133'),
#  Document(metadata={'source': 'cubet_pdfs/SRS_ MyLeaseAudit.pdf', 'page': 13}, page_content='T h e\nu s e r s\nw i l l\nh a v e\nt h e\na c c e s s\nt o\nﬁ l t e r\nt h e\nT o t a l\nA u d i t\nD e t a i l s\nb a s e d  o n ,\n●\nD a t e\n●\nD o c u m e n t  S t a t u s\n●\nD o c u m e n t  S t a g e\n14'),
#  Document(metadata={'source': 'cubet_pdfs/AnaBot(Omang_plai)_SRS_V1.docx.pdf', 'page': 2}, page_content='Revision\nList\nSl.No\nVersion\nDate\nDescription\nAuthor\n1\n1.0\n7th\nMarch\n2024\nInitial\nDraft\nAswathy\nA\nAnabot\n(Omang\nPlai)\n|\nConfidential\nCopyright\n©\n2024,\nCubet.\nAll\nrights\nreserved\n3\nof\n15'),
#  Document(metadata={'source': 'cubet_pdfs/SRS_ Tekdoc.pdf', 'page': 0}, page_content='Software\nRequirement\nSpeciﬁcation\nFor\nTekdoc\nSoftware\nVersion:\n1.0 \nAnnexure\nA\nPrepared\nby:\nKrishnapriya\nCubet\nTechno\nLabs\nPVT\nLTD\n03-June-2020')]

# %% [markdown]
# #### As we can see above, the retrived documents is itself  not relevant for the given query

# %%
question = "Who all prepared the documents?"
response = qa_chain.invoke({"query": question})
print(response["result"])
# Out:
# I don't know.

# %% [markdown]
# ### I have created a simple RAG system above in which the system itself not providing information that is relvant to the query so we make use of Agentic RAG approach to retrive the documents which is more relevant and provide it it to the  LLM for query

# %% [markdown]
# ## Apporach 2 -  Agentic RAG
# Tech stack used - llamaIndex, Open source LLMS (mistral ,llama3.1:8B, llama2)

# %%
#Install requirements
# !pip install python-dotenv
# !pip install llama_index
# !pip install llama-index-llms-ollama
# !pip install llama-index-embeddings-ollama
# Out:
# Collecting python-dotenv
#   Using cached python_dotenv-1.0.1-py3-none-any.whl (19 kB)
# Installing collected packages: python-dotenv
# Successfully installed python-dotenv-1.0.1
# Collecting llama_index
#   Using cached llama_index-0.10.62-py3-none-any.whl (6.8 kB)
# Collecting llama-index-program-openai<0.2.0,>=0.1.3
#   Using cached llama_index_program_openai-0.1.7-py3-none-any.whl (5.3 kB)
# Collecting llama-index-question-gen-openai<0.2.0,>=0.1.2
#   Using cached llama_index_question_gen_openai-0.1.3-py3-none-any.whl (2.9 kB)
# Collecting llama-index-core==0.10.62
#   Using cached llama_index_core-0.10.62-py3-none-any.whl (15.5 MB)
# Collecting llama-index-indices-managed-llama-cloud>=0.2.0
#   Using cached llama_index_indices_managed_llama_cloud-0.2.7-py3-none-any.whl (9.5 kB)
# Collecting llama-index-llms-openai<0.2.0,>=0.1.27
#   Using cached llama_index_llms_openai-0.1.28-py3-none-any.whl (11 kB)
# Collecting llama-index-multi-modal-llms-openai<0.2.0,>=0.1.3
#   Using cached llama_index_multi_modal_llms_openai-0.1.8-py3-none-any.whl (5.9 kB)
# Collecting llama-index-readers-file<0.2.0,>=0.1.4
#   Using cached llama_index_readers_file-0.1.32-py3-none-any.whl (38 kB)
# Collecting llama-index-cli<0.2.0,>=0.1.2
#   Using cached llama_index_cli-0.1.13-py3-none-any.whl (27 kB)
# Collecting llama-index-embeddings-openai<0.2.0,>=0.1.5
#   Using cached llama_index_embeddings_openai-0.1.11-py3-none-any.whl (6.3 kB)
# Collecting llama-index-agent-openai<0.3.0,>=0.1.4
#   Using cached llama_index_agent_openai-0.2.9-py3-none-any.whl (13 kB)
# Collecting llama-index-legacy<0.10.0,>=0.9.48
#   Using cached llama_index_legacy-0.9.48-py3-none-any.whl (2.0 MB)
# Collecting llama-index-readers-llama-parse>=0.1.2
#   Using cached llama_index_readers_llama_parse-0.1.6-py3-none-any.whl (2.5 kB)
# Collecting nltk<4.0.0,>=3.8.1
#   Using cached nltk-3.8.1-py3-none-any.whl (1.5 MB)
# Requirement already satisfied: SQLAlchemy[asyncio]>=1.4.49 in ./jupenv/lib/python3.9/site-packages (from llama-index-core==0.10.62->llama_index) (2.0.32)
# Requirement already satisfied: openai>=1.1.0 in ./jupenv/lib/python3.9/site-packages (from llama-index-core==0.10.62->llama_index) (1.40.0)
# Collecting deprecated>=1.2.9.3
#   Using cached Deprecated-1.2.14-py2.py3-none-any.whl (9.6 kB)
# Requirement already satisfied: nest-asyncio<2.0.0,>=1.5.8 in ./jupenv/lib/python3.9/site-packages (from llama-index-core==0.10.62->llama_index) (1.6.0)
# Requirement already satisfied: numpy<2.0.0 in ./jupenv/lib/python3.9/site-packages (from llama-index-core==0.10.62->llama_index) (1.26.4)
# Requirement already satisfied: pillow>=9.0.0 in ./jupenv/lib/python3.9/site-packages (from llama-index-core==0.10.62->llama_index) (10.4.0)
# Requirement already satisfied: dataclasses-json in ./jupenv/lib/python3.9/site-packages (from llama-index-core==0.10.62->llama_index) (0.6.7)
# Collecting dirtyjson<2.0.0,>=1.0.8
#   Using cached dirtyjson-1.0.8-py3-none-any.whl (25 kB)
# Requirement already satisfied: tqdm<5.0.0,>=4.66.1 in ./jupenv/lib/python3.9/site-packages (from llama-index-core==0.10.62->llama_index) (4.66.5)
# Requirement already satisfied: httpx in ./jupenv/lib/python3.9/site-packages (from llama-index-core==0.10.62->llama_index) (0.27.0)
# Requirement already satisfied: tenacity!=8.4.0,<9.0.0,>=8.2.0 in ./jupenv/lib/python3.9/site-packages (from llama-index-core==0.10.62->llama_index) (8.5.0)
# Collecting wrapt
#   Using cached wrapt-1.16.0-cp39-cp39-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (80 kB)
# Requirement already satisfied: tiktoken>=0.3.3 in ./jupenv/lib/python3.9/site-packages (from llama-index-core==0.10.62->llama_index) (0.7.0)
# Requirement already satisfied: typing-extensions>=4.5.0 in ./jupenv/lib/python3.9/site-packages (from llama-index-core==0.10.62->llama_index) (4.12.2)
# Requirement already satisfied: typing-inspect>=0.8.0 in ./jupenv/lib/python3.9/site-packages (from llama-index-core==0.10.62->llama_index) (0.9.0)
# Requirement already satisfied: fsspec>=2023.5.0 in ./jupenv/lib/python3.9/site-packages (from llama-index-core==0.10.62->llama_index) (2024.6.1)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.6 in ./jupenv/lib/python3.9/site-packages (from llama-index-core==0.10.62->llama_index) (3.10.1)
# Requirement already satisfied: networkx>=3.0 in ./jupenv/lib/python3.9/site-packages (from llama-index-core==0.10.62->llama_index) (3.2.1)
# Requirement already satisfied: requests>=2.31.0 in ./jupenv/lib/python3.9/site-packages (from llama-index-core==0.10.62->llama_index) (2.32.3)
# Collecting pandas
#   Using cached pandas-2.2.2-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (13.1 MB)
# Requirement already satisfied: PyYAML>=6.0.1 in ./jupenv/lib/python3.9/site-packages (from llama-index-core==0.10.62->llama_index) (6.0.2)
# Collecting llama-cloud>=0.0.11
#   Using cached llama_cloud-0.0.12-py3-none-any.whl (169 kB)
# Collecting striprtf<0.0.27,>=0.0.26
#   Using cached striprtf-0.0.26-py3-none-any.whl (6.9 kB)
# Requirement already satisfied: beautifulsoup4<5.0.0,>=4.12.3 in ./jupenv/lib/python3.9/site-packages (from llama-index-readers-file<0.2.0,>=0.1.4->llama_index) (4.12.3)
# Requirement already satisfied: pypdf<5.0.0,>=4.0.1 in ./jupenv/lib/python3.9/site-packages (from llama-index-readers-file<0.2.0,>=0.1.4->llama_index) (4.3.1)
# Collecting llama-parse>=0.4.0
#   Using cached llama_parse-0.4.9-py3-none-any.whl (9.4 kB)
# Collecting click
#   Using cached click-8.1.7-py3-none-any.whl (97 kB)
# Requirement already satisfied: joblib in ./jupenv/lib/python3.9/site-packages (from nltk<4.0.0,>=3.8.1->llama-index-core==0.10.62->llama_index) (1.4.2)
# Requirement already satisfied: regex>=2021.8.3 in ./jupenv/lib/python3.9/site-packages (from nltk<4.0.0,>=3.8.1->llama-index-core==0.10.62->llama_index) (2024.7.24)
# Requirement already satisfied: greenlet!=0.4.17; python_version < "3.13" and (platform_machine == "aarch64" or (platform_machine == "ppc64le" or (platform_machine == "x86_64" or (platform_machine == "amd64" or (platform_machine == "AMD64" or (platform_machine == "win32" or platform_machine == "WIN32")))))) in ./jupenv/lib/python3.9/site-packages (from SQLAlchemy[asyncio]>=1.4.49->llama-index-core==0.10.62->llama_index) (3.0.3)
# Requirement already satisfied: pydantic<3,>=1.9.0 in ./jupenv/lib/python3.9/site-packages (from openai>=1.1.0->llama-index-core==0.10.62->llama_index) (2.8.2)
# Requirement already satisfied: sniffio in ./jupenv/lib/python3.9/site-packages (from openai>=1.1.0->llama-index-core==0.10.62->llama_index) (1.3.1)
# Requirement already satisfied: distro<2,>=1.7.0 in ./jupenv/lib/python3.9/site-packages (from openai>=1.1.0->llama-index-core==0.10.62->llama_index) (1.9.0)
# Requirement already satisfied: jiter<1,>=0.4.0 in ./jupenv/lib/python3.9/site-packages (from openai>=1.1.0->llama-index-core==0.10.62->llama_index) (0.5.0)
# Requirement already satisfied: anyio<5,>=3.5.0 in ./jupenv/lib/python3.9/site-packages (from openai>=1.1.0->llama-index-core==0.10.62->llama_index) (4.4.0)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in ./jupenv/lib/python3.9/site-packages (from dataclasses-json->llama-index-core==0.10.62->llama_index) (3.21.3)
# Requirement already satisfied: idna in ./jupenv/lib/python3.9/site-packages (from httpx->llama-index-core==0.10.62->llama_index) (3.7)
# Requirement already satisfied: certifi in ./jupenv/lib/python3.9/site-packages (from httpx->llama-index-core==0.10.62->llama_index) (2024.7.4)
# Requirement already satisfied: httpcore==1.* in ./jupenv/lib/python3.9/site-packages (from httpx->llama-index-core==0.10.62->llama_index) (1.0.5)
# Requirement already satisfied: mypy-extensions>=0.3.0 in ./jupenv/lib/python3.9/site-packages (from typing-inspect>=0.8.0->llama-index-core==0.10.62->llama_index) (1.0.0)
# Requirement already satisfied: aiosignal>=1.1.2 in ./jupenv/lib/python3.9/site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core==0.10.62->llama_index) (1.3.1)
# Requirement already satisfied: async-timeout<5.0,>=4.0; python_version < "3.11" in ./jupenv/lib/python3.9/site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core==0.10.62->llama_index) (4.0.3)
# Requirement already satisfied: attrs>=17.3.0 in ./jupenv/lib/python3.9/site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core==0.10.62->llama_index) (24.2.0)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in ./jupenv/lib/python3.9/site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core==0.10.62->llama_index) (2.3.4)
# Requirement already satisfied: multidict<7.0,>=4.5 in ./jupenv/lib/python3.9/site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core==0.10.62->llama_index) (6.0.5)
# Requirement already satisfied: yarl<2.0,>=1.0 in ./jupenv/lib/python3.9/site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core==0.10.62->llama_index) (1.9.4)
# Requirement already satisfied: frozenlist>=1.1.1 in ./jupenv/lib/python3.9/site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core==0.10.62->llama_index) (1.4.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in ./jupenv/lib/python3.9/site-packages (from requests>=2.31.0->llama-index-core==0.10.62->llama_index) (3.3.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in ./jupenv/lib/python3.9/site-packages (from requests>=2.31.0->llama-index-core==0.10.62->llama_index) (2.2.2)
# Collecting pytz>=2020.1
#   Using cached pytz-2024.1-py2.py3-none-any.whl (505 kB)
# Collecting tzdata>=2022.7
#   Using cached tzdata-2024.1-py2.py3-none-any.whl (345 kB)
# Requirement already satisfied: python-dateutil>=2.8.2 in ./jupenv/lib/python3.9/site-packages (from pandas->llama-index-core==0.10.62->llama_index) (2.9.0.post0)
# Requirement already satisfied: soupsieve>1.2 in ./jupenv/lib/python3.9/site-packages (from beautifulsoup4<5.0.0,>=4.12.3->llama-index-readers-file<0.2.0,>=0.1.4->llama_index) (2.5)
# Requirement already satisfied: pydantic-core==2.20.1 in ./jupenv/lib/python3.9/site-packages (from pydantic<3,>=1.9.0->openai>=1.1.0->llama-index-core==0.10.62->llama_index) (2.20.1)
# Requirement already satisfied: annotated-types>=0.4.0 in ./jupenv/lib/python3.9/site-packages (from pydantic<3,>=1.9.0->openai>=1.1.0->llama-index-core==0.10.62->llama_index) (0.7.0)
# Requirement already satisfied: exceptiongroup>=1.0.2; python_version < "3.11" in ./jupenv/lib/python3.9/site-packages (from anyio<5,>=3.5.0->openai>=1.1.0->llama-index-core==0.10.62->llama_index) (1.2.2)
# Requirement already satisfied: packaging>=17.0 in ./jupenv/lib/python3.9/site-packages (from marshmallow<4.0.0,>=3.18.0->dataclasses-json->llama-index-core==0.10.62->llama_index) (24.1)
# Requirement already satisfied: h11<0.15,>=0.13 in ./jupenv/lib/python3.9/site-packages (from httpcore==1.*->httpx->llama-index-core==0.10.62->llama_index) (0.14.0)
# Requirement already satisfied: six>=1.5 in ./jupenv/lib/python3.9/site-packages (from python-dateutil>=2.8.2->pandas->llama-index-core==0.10.62->llama_index) (1.16.0)
# Installing collected packages: click, nltk, wrapt, deprecated, dirtyjson, pytz, tzdata, pandas, llama-index-core, llama-index-llms-openai, llama-index-agent-openai, llama-index-program-openai, llama-index-question-gen-openai, llama-cloud, llama-index-indices-managed-llama-cloud, llama-index-multi-modal-llms-openai, striprtf, llama-index-readers-file, llama-index-embeddings-openai, llama-index-cli, llama-index-legacy, llama-parse, llama-index-readers-llama-parse, llama-index
# Successfully installed click-8.1.7 deprecated-1.2.14 dirtyjson-1.0.8 llama-cloud-0.0.12 llama-index-0.10.62 llama-index-agent-openai-0.2.9 llama-index-cli-0.1.13 llama-index-core-0.10.62 llama-index-embeddings-openai-0.1.11 llama-index-indices-managed-llama-cloud-0.2.7 llama-index-legacy-0.9.48 llama-index-llms-openai-0.1.28 llama-index-multi-modal-llms-openai-0.1.8 llama-index-program-openai-0.1.7 llama-index-question-gen-openai-0.1.3 llama-index-readers-file-0.1.32 llama-index-readers-llama-parse-0.1.6 llama-parse-0.4.9 nltk-3.8.1 pandas-2.2.2 pytz-2024.1 striprtf-0.0.26 tzdata-2024.1 wrapt-1.16.0
# Collecting llama-index-llms-ollama
#   Using cached llama_index_llms_ollama-0.2.2-py3-none-any.whl (4.4 kB)
# Requirement already satisfied: ollama>=0.3.0 in ./jupenv/lib/python3.9/site-packages (from llama-index-llms-ollama) (0.3.1)
# Requirement already satisfied: llama-index-core<0.11.0,>=0.10.1 in ./jupenv/lib/python3.9/site-packages (from llama-index-llms-ollama) (0.10.62)
# Requirement already satisfied: httpx<0.28.0,>=0.27.0 in ./jupenv/lib/python3.9/site-packages (from ollama>=0.3.0->llama-index-llms-ollama) (0.27.0)
# Requirement already satisfied: requests>=2.31.0 in ./jupenv/lib/python3.9/site-packages (from llama-index-core<0.11.0,>=0.10.1->llama-index-llms-ollama) (2.32.3)
# Requirement already satisfied: fsspec>=2023.5.0 in ./jupenv/lib/python3.9/site-packages (from llama-index-core<0.11.0,>=0.10.1->llama-index-llms-ollama) (2024.6.1)
# Requirement already satisfied: tiktoken>=0.3.3 in ./jupenv/lib/python3.9/site-packages (from llama-index-core<0.11.0,>=0.10.1->llama-index-llms-ollama) (0.7.0)
# Requirement already satisfied: pillow>=9.0.0 in ./jupenv/lib/python3.9/site-packages (from llama-index-core<0.11.0,>=0.10.1->llama-index-llms-ollama) (10.4.0)
# Requirement already satisfied: deprecated>=1.2.9.3 in ./jupenv/lib/python3.9/site-packages (from llama-index-core<0.11.0,>=0.10.1->llama-index-llms-ollama) (1.2.14)
# Requirement already satisfied: tqdm<5.0.0,>=4.66.1 in ./jupenv/lib/python3.9/site-packages (from llama-index-core<0.11.0,>=0.10.1->llama-index-llms-ollama) (4.66.5)
# Requirement already satisfied: dataclasses-json in ./jupenv/lib/python3.9/site-packages (from llama-index-core<0.11.0,>=0.10.1->llama-index-llms-ollama) (0.6.7)
# Requirement already satisfied: dirtyjson<2.0.0,>=1.0.8 in ./jupenv/lib/python3.9/site-packages (from llama-index-core<0.11.0,>=0.10.1->llama-index-llms-ollama) (1.0.8)
# Requirement already satisfied: nltk<4.0.0,>=3.8.1 in ./jupenv/lib/python3.9/site-packages (from llama-index-core<0.11.0,>=0.10.1->llama-index-llms-ollama) (3.8.1)
# Requirement already satisfied: pandas in ./jupenv/lib/python3.9/site-packages (from llama-index-core<0.11.0,>=0.10.1->llama-index-llms-ollama) (2.2.2)
# Requirement already satisfied: tenacity!=8.4.0,<9.0.0,>=8.2.0 in ./jupenv/lib/python3.9/site-packages (from llama-index-core<0.11.0,>=0.10.1->llama-index-llms-ollama) (8.5.0)
# Requirement already satisfied: numpy<2.0.0 in ./jupenv/lib/python3.9/site-packages (from llama-index-core<0.11.0,>=0.10.1->llama-index-llms-ollama) (1.26.4)
# Requirement already satisfied: networkx>=3.0 in ./jupenv/lib/python3.9/site-packages (from llama-index-core<0.11.0,>=0.10.1->llama-index-llms-ollama) (3.2.1)
# Requirement already satisfied: PyYAML>=6.0.1 in ./jupenv/lib/python3.9/site-packages (from llama-index-core<0.11.0,>=0.10.1->llama-index-llms-ollama) (6.0.2)
# Requirement already satisfied: SQLAlchemy[asyncio]>=1.4.49 in ./jupenv/lib/python3.9/site-packages (from llama-index-core<0.11.0,>=0.10.1->llama-index-llms-ollama) (2.0.32)
# Requirement already satisfied: openai>=1.1.0 in ./jupenv/lib/python3.9/site-packages (from llama-index-core<0.11.0,>=0.10.1->llama-index-llms-ollama) (1.40.0)
# Requirement already satisfied: nest-asyncio<2.0.0,>=1.5.8 in ./jupenv/lib/python3.9/site-packages (from llama-index-core<0.11.0,>=0.10.1->llama-index-llms-ollama) (1.6.0)
# Requirement already satisfied: wrapt in ./jupenv/lib/python3.9/site-packages (from llama-index-core<0.11.0,>=0.10.1->llama-index-llms-ollama) (1.16.0)
# Requirement already satisfied: typing-extensions>=4.5.0 in ./jupenv/lib/python3.9/site-packages (from llama-index-core<0.11.0,>=0.10.1->llama-index-llms-ollama) (4.12.2)
# Requirement already satisfied: typing-inspect>=0.8.0 in ./jupenv/lib/python3.9/site-packages (from llama-index-core<0.11.0,>=0.10.1->llama-index-llms-ollama) (0.9.0)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.6 in ./jupenv/lib/python3.9/site-packages (from llama-index-core<0.11.0,>=0.10.1->llama-index-llms-ollama) (3.10.1)
# Requirement already satisfied: idna in ./jupenv/lib/python3.9/site-packages (from httpx<0.28.0,>=0.27.0->ollama>=0.3.0->llama-index-llms-ollama) (3.7)
# Requirement already satisfied: anyio in ./jupenv/lib/python3.9/site-packages (from httpx<0.28.0,>=0.27.0->ollama>=0.3.0->llama-index-llms-ollama) (4.4.0)
# Requirement already satisfied: sniffio in ./jupenv/lib/python3.9/site-packages (from httpx<0.28.0,>=0.27.0->ollama>=0.3.0->llama-index-llms-ollama) (1.3.1)
# Requirement already satisfied: httpcore==1.* in ./jupenv/lib/python3.9/site-packages (from httpx<0.28.0,>=0.27.0->ollama>=0.3.0->llama-index-llms-ollama) (1.0.5)
# Requirement already satisfied: certifi in ./jupenv/lib/python3.9/site-packages (from httpx<0.28.0,>=0.27.0->ollama>=0.3.0->llama-index-llms-ollama) (2024.7.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in ./jupenv/lib/python3.9/site-packages (from requests>=2.31.0->llama-index-core<0.11.0,>=0.10.1->llama-index-llms-ollama) (2.2.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in ./jupenv/lib/python3.9/site-packages (from requests>=2.31.0->llama-index-core<0.11.0,>=0.10.1->llama-index-llms-ollama) (3.3.2)
# Requirement already satisfied: regex>=2022.1.18 in ./jupenv/lib/python3.9/site-packages (from tiktoken>=0.3.3->llama-index-core<0.11.0,>=0.10.1->llama-index-llms-ollama) (2024.7.24)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in ./jupenv/lib/python3.9/site-packages (from dataclasses-json->llama-index-core<0.11.0,>=0.10.1->llama-index-llms-ollama) (3.21.3)
# Requirement already satisfied: click in ./jupenv/lib/python3.9/site-packages (from nltk<4.0.0,>=3.8.1->llama-index-core<0.11.0,>=0.10.1->llama-index-llms-ollama) (8.1.7)
# Requirement already satisfied: joblib in ./jupenv/lib/python3.9/site-packages (from nltk<4.0.0,>=3.8.1->llama-index-core<0.11.0,>=0.10.1->llama-index-llms-ollama) (1.4.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in ./jupenv/lib/python3.9/site-packages (from pandas->llama-index-core<0.11.0,>=0.10.1->llama-index-llms-ollama) (2.9.0.post0)
# Requirement already satisfied: tzdata>=2022.7 in ./jupenv/lib/python3.9/site-packages (from pandas->llama-index-core<0.11.0,>=0.10.1->llama-index-llms-ollama) (2024.1)
# Requirement already satisfied: pytz>=2020.1 in ./jupenv/lib/python3.9/site-packages (from pandas->llama-index-core<0.11.0,>=0.10.1->llama-index-llms-ollama) (2024.1)
# Requirement already satisfied: greenlet!=0.4.17; python_version < "3.13" and (platform_machine == "aarch64" or (platform_machine == "ppc64le" or (platform_machine == "x86_64" or (platform_machine == "amd64" or (platform_machine == "AMD64" or (platform_machine == "win32" or platform_machine == "WIN32")))))) in ./jupenv/lib/python3.9/site-packages (from SQLAlchemy[asyncio]>=1.4.49->llama-index-core<0.11.0,>=0.10.1->llama-index-llms-ollama) (3.0.3)
# Requirement already satisfied: pydantic<3,>=1.9.0 in ./jupenv/lib/python3.9/site-packages (from openai>=1.1.0->llama-index-core<0.11.0,>=0.10.1->llama-index-llms-ollama) (2.8.2)
# Requirement already satisfied: distro<2,>=1.7.0 in ./jupenv/lib/python3.9/site-packages (from openai>=1.1.0->llama-index-core<0.11.0,>=0.10.1->llama-index-llms-ollama) (1.9.0)
# Requirement already satisfied: jiter<1,>=0.4.0 in ./jupenv/lib/python3.9/site-packages (from openai>=1.1.0->llama-index-core<0.11.0,>=0.10.1->llama-index-llms-ollama) (0.5.0)
# Requirement already satisfied: mypy-extensions>=0.3.0 in ./jupenv/lib/python3.9/site-packages (from typing-inspect>=0.8.0->llama-index-core<0.11.0,>=0.10.1->llama-index-llms-ollama) (1.0.0)
# Requirement already satisfied: yarl<2.0,>=1.0 in ./jupenv/lib/python3.9/site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.11.0,>=0.10.1->llama-index-llms-ollama) (1.9.4)
# Requirement already satisfied: frozenlist>=1.1.1 in ./jupenv/lib/python3.9/site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.11.0,>=0.10.1->llama-index-llms-ollama) (1.4.1)
# Requirement already satisfied: async-timeout<5.0,>=4.0; python_version < "3.11" in ./jupenv/lib/python3.9/site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.11.0,>=0.10.1->llama-index-llms-ollama) (4.0.3)
# Requirement already satisfied: attrs>=17.3.0 in ./jupenv/lib/python3.9/site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.11.0,>=0.10.1->llama-index-llms-ollama) (24.2.0)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in ./jupenv/lib/python3.9/site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.11.0,>=0.10.1->llama-index-llms-ollama) (2.3.4)
# Requirement already satisfied: aiosignal>=1.1.2 in ./jupenv/lib/python3.9/site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.11.0,>=0.10.1->llama-index-llms-ollama) (1.3.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in ./jupenv/lib/python3.9/site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.11.0,>=0.10.1->llama-index-llms-ollama) (6.0.5)
# Requirement already satisfied: exceptiongroup>=1.0.2; python_version < "3.11" in ./jupenv/lib/python3.9/site-packages (from anyio->httpx<0.28.0,>=0.27.0->ollama>=0.3.0->llama-index-llms-ollama) (1.2.2)
# Requirement already satisfied: h11<0.15,>=0.13 in ./jupenv/lib/python3.9/site-packages (from httpcore==1.*->httpx<0.28.0,>=0.27.0->ollama>=0.3.0->llama-index-llms-ollama) (0.14.0)
# Requirement already satisfied: packaging>=17.0 in ./jupenv/lib/python3.9/site-packages (from marshmallow<4.0.0,>=3.18.0->dataclasses-json->llama-index-core<0.11.0,>=0.10.1->llama-index-llms-ollama) (24.1)
# Requirement already satisfied: six>=1.5 in ./jupenv/lib/python3.9/site-packages (from python-dateutil>=2.8.2->pandas->llama-index-core<0.11.0,>=0.10.1->llama-index-llms-ollama) (1.16.0)
# Requirement already satisfied: pydantic-core==2.20.1 in ./jupenv/lib/python3.9/site-packages (from pydantic<3,>=1.9.0->openai>=1.1.0->llama-index-core<0.11.0,>=0.10.1->llama-index-llms-ollama) (2.20.1)
# Requirement already satisfied: annotated-types>=0.4.0 in ./jupenv/lib/python3.9/site-packages (from pydantic<3,>=1.9.0->openai>=1.1.0->llama-index-core<0.11.0,>=0.10.1->llama-index-llms-ollama) (0.7.0)
# Installing collected packages: llama-index-llms-ollama
# Successfully installed llama-index-llms-ollama-0.2.2
# Collecting llama-index-embeddings-ollama
#   Using cached llama_index_embeddings_ollama-0.1.3-py3-none-any.whl (2.9 kB)
# Requirement already satisfied: llama-index-core<0.11.0,>=0.10.1 in ./jupenv/lib/python3.9/site-packages (from llama-index-embeddings-ollama) (0.10.62)
# Requirement already satisfied: tiktoken>=0.3.3 in ./jupenv/lib/python3.9/site-packages (from llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-ollama) (0.7.0)
# Requirement already satisfied: tqdm<5.0.0,>=4.66.1 in ./jupenv/lib/python3.9/site-packages (from llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-ollama) (4.66.5)
# Requirement already satisfied: wrapt in ./jupenv/lib/python3.9/site-packages (from llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-ollama) (1.16.0)
# Requirement already satisfied: networkx>=3.0 in ./jupenv/lib/python3.9/site-packages (from llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-ollama) (3.2.1)
# Requirement already satisfied: typing-extensions>=4.5.0 in ./jupenv/lib/python3.9/site-packages (from llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-ollama) (4.12.2)
# Requirement already satisfied: tenacity!=8.4.0,<9.0.0,>=8.2.0 in ./jupenv/lib/python3.9/site-packages (from llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-ollama) (8.5.0)
# Requirement already satisfied: deprecated>=1.2.9.3 in ./jupenv/lib/python3.9/site-packages (from llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-ollama) (1.2.14)
# Requirement already satisfied: nltk<4.0.0,>=3.8.1 in ./jupenv/lib/python3.9/site-packages (from llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-ollama) (3.8.1)
# Requirement already satisfied: nest-asyncio<2.0.0,>=1.5.8 in ./jupenv/lib/python3.9/site-packages (from llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-ollama) (1.6.0)
# Requirement already satisfied: pandas in ./jupenv/lib/python3.9/site-packages (from llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-ollama) (2.2.2)
# Requirement already satisfied: openai>=1.1.0 in ./jupenv/lib/python3.9/site-packages (from llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-ollama) (1.40.0)
# Requirement already satisfied: SQLAlchemy[asyncio]>=1.4.49 in ./jupenv/lib/python3.9/site-packages (from llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-ollama) (2.0.32)
# Requirement already satisfied: dirtyjson<2.0.0,>=1.0.8 in ./jupenv/lib/python3.9/site-packages (from llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-ollama) (1.0.8)
# Requirement already satisfied: numpy<2.0.0 in ./jupenv/lib/python3.9/site-packages (from llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-ollama) (1.26.4)
# Requirement already satisfied: PyYAML>=6.0.1 in ./jupenv/lib/python3.9/site-packages (from llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-ollama) (6.0.2)
# Requirement already satisfied: dataclasses-json in ./jupenv/lib/python3.9/site-packages (from llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-ollama) (0.6.7)
# Requirement already satisfied: httpx in ./jupenv/lib/python3.9/site-packages (from llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-ollama) (0.27.0)
# Requirement already satisfied: requests>=2.31.0 in ./jupenv/lib/python3.9/site-packages (from llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-ollama) (2.32.3)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.6 in ./jupenv/lib/python3.9/site-packages (from llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-ollama) (3.10.1)
# Requirement already satisfied: pillow>=9.0.0 in ./jupenv/lib/python3.9/site-packages (from llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-ollama) (10.4.0)
# Requirement already satisfied: fsspec>=2023.5.0 in ./jupenv/lib/python3.9/site-packages (from llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-ollama) (2024.6.1)
# Requirement already satisfied: typing-inspect>=0.8.0 in ./jupenv/lib/python3.9/site-packages (from llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-ollama) (0.9.0)
# Requirement already satisfied: regex>=2022.1.18 in ./jupenv/lib/python3.9/site-packages (from tiktoken>=0.3.3->llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-ollama) (2024.7.24)
# Requirement already satisfied: joblib in ./jupenv/lib/python3.9/site-packages (from nltk<4.0.0,>=3.8.1->llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-ollama) (1.4.2)
# Requirement already satisfied: click in ./jupenv/lib/python3.9/site-packages (from nltk<4.0.0,>=3.8.1->llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-ollama) (8.1.7)
# Requirement already satisfied: tzdata>=2022.7 in ./jupenv/lib/python3.9/site-packages (from pandas->llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-ollama) (2024.1)
# Requirement already satisfied: pytz>=2020.1 in ./jupenv/lib/python3.9/site-packages (from pandas->llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-ollama) (2024.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in ./jupenv/lib/python3.9/site-packages (from pandas->llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-ollama) (2.9.0.post0)
# Requirement already satisfied: anyio<5,>=3.5.0 in ./jupenv/lib/python3.9/site-packages (from openai>=1.1.0->llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-ollama) (4.4.0)
# Requirement already satisfied: distro<2,>=1.7.0 in ./jupenv/lib/python3.9/site-packages (from openai>=1.1.0->llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-ollama) (1.9.0)
# Requirement already satisfied: pydantic<3,>=1.9.0 in ./jupenv/lib/python3.9/site-packages (from openai>=1.1.0->llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-ollama) (2.8.2)
# Requirement already satisfied: sniffio in ./jupenv/lib/python3.9/site-packages (from openai>=1.1.0->llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-ollama) (1.3.1)
# Requirement already satisfied: jiter<1,>=0.4.0 in ./jupenv/lib/python3.9/site-packages (from openai>=1.1.0->llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-ollama) (0.5.0)
# Requirement already satisfied: greenlet!=0.4.17; python_version < "3.13" and (platform_machine == "aarch64" or (platform_machine == "ppc64le" or (platform_machine == "x86_64" or (platform_machine == "amd64" or (platform_machine == "AMD64" or (platform_machine == "win32" or platform_machine == "WIN32")))))) in ./jupenv/lib/python3.9/site-packages (from SQLAlchemy[asyncio]>=1.4.49->llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-ollama) (3.0.3)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in ./jupenv/lib/python3.9/site-packages (from dataclasses-json->llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-ollama) (3.21.3)
# Requirement already satisfied: certifi in ./jupenv/lib/python3.9/site-packages (from httpx->llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-ollama) (2024.7.4)
# Requirement already satisfied: idna in ./jupenv/lib/python3.9/site-packages (from httpx->llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-ollama) (3.7)
# Requirement already satisfied: httpcore==1.* in ./jupenv/lib/python3.9/site-packages (from httpx->llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-ollama) (1.0.5)
# Requirement already satisfied: charset-normalizer<4,>=2 in ./jupenv/lib/python3.9/site-packages (from requests>=2.31.0->llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-ollama) (3.3.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in ./jupenv/lib/python3.9/site-packages (from requests>=2.31.0->llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-ollama) (2.2.2)
# Requirement already satisfied: attrs>=17.3.0 in ./jupenv/lib/python3.9/site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-ollama) (24.2.0)
# Requirement already satisfied: async-timeout<5.0,>=4.0; python_version < "3.11" in ./jupenv/lib/python3.9/site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-ollama) (4.0.3)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in ./jupenv/lib/python3.9/site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-ollama) (2.3.4)
# Requirement already satisfied: aiosignal>=1.1.2 in ./jupenv/lib/python3.9/site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-ollama) (1.3.1)
# Requirement already satisfied: yarl<2.0,>=1.0 in ./jupenv/lib/python3.9/site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-ollama) (1.9.4)
# Requirement already satisfied: frozenlist>=1.1.1 in ./jupenv/lib/python3.9/site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-ollama) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in ./jupenv/lib/python3.9/site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-ollama) (6.0.5)
# Requirement already satisfied: mypy-extensions>=0.3.0 in ./jupenv/lib/python3.9/site-packages (from typing-inspect>=0.8.0->llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-ollama) (1.0.0)
# Requirement already satisfied: six>=1.5 in ./jupenv/lib/python3.9/site-packages (from python-dateutil>=2.8.2->pandas->llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-ollama) (1.16.0)
# Requirement already satisfied: exceptiongroup>=1.0.2; python_version < "3.11" in ./jupenv/lib/python3.9/site-packages (from anyio<5,>=3.5.0->openai>=1.1.0->llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-ollama) (1.2.2)
# Requirement already satisfied: pydantic-core==2.20.1 in ./jupenv/lib/python3.9/site-packages (from pydantic<3,>=1.9.0->openai>=1.1.0->llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-ollama) (2.20.1)
# Requirement already satisfied: annotated-types>=0.4.0 in ./jupenv/lib/python3.9/site-packages (from pydantic<3,>=1.9.0->openai>=1.1.0->llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-ollama) (0.7.0)
# Requirement already satisfied: packaging>=17.0 in ./jupenv/lib/python3.9/site-packages (from marshmallow<4.0.0,>=3.18.0->dataclasses-json->llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-ollama) (24.1)
# Requirement already satisfied: h11<0.15,>=0.13 in ./jupenv/lib/python3.9/site-packages (from httpcore==1.*->httpx->llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-ollama) (0.14.0)
# Installing collected packages: llama-index-embeddings-ollama
# Successfully installed llama-index-embeddings-ollama-0.1.3

# %% [markdown]
# #### Link to install ollama and download the model locally
#
# https://ollama.com/

# %%
#Checking for ollama models - Install Ollama by using the link given above. 
#Once installed, install model using ollama run <model name> command (Replace model name with the model that you need to install). 
#Refer the above linke
# !ollama list
# Out:
# NAME                   	ID          	SIZE  	MODIFIED
# mistral:latest         	f974a74358d6	4.1 GB	3 hours ago
# nomic-embed-text:latest	0a109f422b47	274 MB	4 hours ago
# llama2:latest          	78e26419b446	3.8 GB	15 hours ago
# llama3.1:8b            	62757c860e01	4.7 GB	18 hours ago

# %% [markdown]
# #### We can either use open source models or can use proprietary  models like openai - If you have the openai key you can provide below.

# %%
OPENAI_API_KEY = os.getenv('OPENAI_API_KEY', "api_key_here")

# %%
# from llama_index.core.query_engine.router_query_engine import RouterQueryEngine
# from llama_index.core.selectors import LLMSingleSelector
# from llama_index.core.tools import QueryEngineTool
from llama_index.core import SummaryIndex, VectorStoreIndex
from llama_index.core import Settings
from llama_index.llms.openai import OpenAI
from llama_index.embeddings.openai import OpenAIEmbedding
from llama_index.llms.ollama import Ollama
from llama_index.embeddings.ollama import OllamaEmbedding
from llama_index.core.node_parser import SentenceSplitter
from llama_index.core import SimpleDirectoryReader
from llama_index.core.tools import QueryEngineTool
from llama_index.core.agent import FunctionCallingAgentWorker
from llama_index.core.agent import AgentRunner
from pathlib import Path
import os
import re
from typing import Tuple

# %% [markdown]
# ### Lets have a look at how the Agentic RAG works in a single document

# %%
#Suppose I have one pdf in the directory called cubet_pdfs
documents = SimpleDirectoryReader(input_files=["cubet_pdfs/AnaBot(Omang_plai)_SRS_V1.docx.pdf"]).load_data()
splitter = SentenceSplitter(chunk_size=1024)
nodes = splitter.get_nodes_from_documents(documents)
nodes[0]
# Out:
# TextNode(id_='c06009b0-d110-4552-91e6-64004d55343b', embedding=None, metadata={'page_label': '1', 'file_name': 'AnaBot(Omang_plai)_SRS_V1.docx.pdf', 'file_path': 'cubet_pdfs/AnaBot(Omang_plai)_SRS_V1.docx.pdf', 'file_type': 'application/pdf', 'file_size': 184818, 'creation_date': '2024-08-06', 'last_modified_date': '2024-08-06'}, excluded_embed_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], excluded_llm_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], relationships={<NodeRelationship.SOURCE: '1'>: RelatedNodeInfo(node_id='cd5a56ba-f2d2-4bcc-b99e-ac93bb44968c', node_type=<ObjectType.DOCUMENT: '4'>, metadata={'page_label': '1', 'file_name': 'AnaBot(Omang_plai)_SRS_V1.docx.pdf', 'file_path': 'cubet_pdfs/AnaBot(Omang_plai)_SRS_V1.docx.pdf', 'file_type': 'application/pdf', 'file_size': 184818, 'creation_date': '2024-08-06', 'last_modified_date': '2024-08-06'}, hash='f92d361a863077e8aef6d8e20f236d332742d9fb52f2fc76a95b66b97be09de5')}, text='Software\nRequirement\nSpecification\nFor\nAnaBot\n(Omang\nPlai)\nVersion:\n1.0\nPrepared\nby:\nAswathy\nA\nCubet\nTechno\nLabs\nPVT\nLTD\n07-03-2024\n1', mimetype='text/plain', start_char_idx=0, end_char_idx=133, text_template='{metadata_str}\n\n{content}', metadata_template='{key}: {value}', metadata_seperator='\n')

# %% [markdown]
# #### In order to use models like "nomic-embed-text:latest" and "llama3.1:8b" you need to install ollama and then run models from the link mentioned below in terminal/CLI
#
#
#
# https://ollama.com/library
#
# Note: You can also use hugging face embeddings

# %%
Settings.llm = Ollama(model="llama3.1:8b",request_timeout=120.0)
Settings.embed_model = OllamaEmbedding(model_name="nomic-embed-text:latest")
# Settings.llm = OpenAI(model="gpt-4o-mini", api_key=OPENAI_API_KEY)
# Settings.embed_model = OpenAIEmbedding(model="text-embedding-ada-002", api_key=OPENAI_API_KEY)

# summary index
summary_index = SummaryIndex(nodes)
# vector store index
vector_index = VectorStoreIndex(nodes)

# summary query engine
summary_query_engine = summary_index.as_query_engine(
    response_mode="tree_summarize",
    use_async=True,
)

# vector query engine
vector_query_engine = vector_index.as_query_engine()

# %%
summary_tool = QueryEngineTool.from_defaults(
    query_engine=summary_query_engine,
    description=(
        "Useful for summarization questions related to the AnaBot(Omang_plai)_SRS_V1 paper."
    ),
)

vector_tool = QueryEngineTool.from_defaults(
    query_engine=vector_query_engine,
    description=(
        "Useful for retrieving specific context from the the AnaBot(Omang_plai)_SRS_V1 paper."
    ),
)

# %%
llm = Ollama(model="llama3.1:8b",request_timeout=3000.0)
# llm = OpenAI(model="gpt-4o-mini", temperature=0, api_key=OPENAI_API_KEY )

# %%
agent_worker = FunctionCallingAgentWorker.from_tools(
    tools=[summary_tool, vector_tool],
    llm=llm,
    verbose=True,
)

agent = AgentRunner(agent_worker)

# %%
response = agent.query(
    "who prepared the document"
)
print(str(response))
# Out:
# Added user message to memory: who prepared the document
# === Calling Function ===
# Calling function: query_engine_tool with args: {"input": "Who prepared the AnaBot(Omang_plai)_SRS_V1 document?"}
# === Function Output ===
# Aswathy A prepared the AnaBot(Omang_plai)_SRS_V1 document.
# === LLM Response ===
# The AnaBot(Omang_plai)_SRS_V1 document was prepared by Aswathy A.
# The AnaBot(Omang_plai)_SRS_V1 document was prepared by Aswathy A.

# %% [markdown]
# ## Multiple document query

# %%
def sanitize_tool_name(name):
    return re.sub(r'[^a-zA-Z0-9_-]', '_', name)
    
def create_doc_tools(
    document_fp: str,
    doc_name: str,
    verbose: bool = True,
) -> Tuple[QueryEngineTool, QueryEngineTool]:
    documents = SimpleDirectoryReader(input_files=[document_fp]).load_data()
    splitter = SentenceSplitter(chunk_size=1024)
    nodes = splitter.get_nodes_from_documents(documents)

    
    Settings.llm = Ollama(model="llama3.1:8b",request_timeout=120.0)
    Settings.embed_model = OllamaEmbedding(model_name="nomic-embed-text:latest")
    # Settings.llm = OpenAI(model="gpt-4o-mini", api_key=OPENAI_API_KEY)
    # Settings.embed_model = OpenAIEmbedding(model="text-embedding-ada-002", api_key=OPENAI_API_KEY)

    # summary index
    summary_index = SummaryIndex(nodes)
    # vector store index
    vector_index = VectorStoreIndex(nodes)

    # summary query engine
    summary_query_engine = summary_index.as_query_engine(
        response_mode="tree_summarize",
        use_async=True,
    )

    # vector query engine
    vector_query_engine = vector_index.as_query_engine()

    summary_tool = QueryEngineTool.from_defaults(
        name=sanitize_tool_name(f"{doc_name}_summary_query_engine_tool"),
        query_engine=summary_query_engine,
        description=(
            f"Useful for summarization questions related to the {doc_name}."
        ),
    )

    vector_tool = QueryEngineTool.from_defaults(
        name=sanitize_tool_name(f"{doc_name}_vector_query_engine_tool"),
        query_engine=vector_query_engine,
        description=(
            f"Useful for retrieving specific context from the the {doc_name}."
        ),
    )

    return vector_tool, summary_tool

# %%
directory = "cubet_pdfs"
papers = [f"./{directory}/{filename}" for filename in os.listdir(directory) if filename.endswith('.pdf')]
papers
# Out:
# ['./cubet_pdfs/SRS_ Tekdoc.pdf',
#  './cubet_pdfs/AnaBot(Omang_plai)_SRS_V1.docx.pdf',
#  './cubet_pdfs/OPD Booster-SRS V3.0.pdf',
#  './cubet_pdfs/SRS_ MyLeaseAudit.pdf',
#  './cubet_pdfs/Bloom app_v1.1_SRS.docx.pdf']

# %%
paper_to_tools_dict = {}
for paper in papers:
    print(f"Creating {paper} tool")
    path = Path(paper)
    vector_tool, summary_tool = create_doc_tools(doc_name=path.stem, document_fp=path)
    paper_to_tools_dict[path.stem] = [vector_tool, summary_tool]
# Out:
# Creating ./cubet_pdfs/SRS_ Tekdoc.pdf tool
# Creating ./cubet_pdfs/AnaBot(Omang_plai)_SRS_V1.docx.pdf tool
# Creating ./cubet_pdfs/OPD Booster-SRS V3.0.pdf tool
# Creating ./cubet_pdfs/SRS_ MyLeaseAudit.pdf tool
# Creating ./cubet_pdfs/Bloom app_v1.1_SRS.docx.pdf tool

# %%
paper_to_tools_dict
# Out:
# {'SRS_ Tekdoc': [<llama_index.core.tools.query_engine.QueryEngineTool at 0x7f8d00e0e5e0>,
#   <llama_index.core.tools.query_engine.QueryEngineTool at 0x7f8cc382efa0>],
#  'AnaBot(Omang_plai)_SRS_V1.docx': [<llama_index.core.tools.query_engine.QueryEngineTool at 0x7f8d00e99d90>,
#   <llama_index.core.tools.query_engine.QueryEngineTool at 0x7f8d00e99e20>],
#  'OPD Booster-SRS V3.0': [<llama_index.core.tools.query_engine.QueryEngineTool at 0x7f8d00bea370>,
#   <llama_index.core.tools.query_engine.QueryEngineTool at 0x7f8d00bea160>],
#  'SRS_ MyLeaseAudit': [<llama_index.core.tools.query_engine.QueryEngineTool at 0x7f8d00e09d60>,
#   <llama_index.core.tools.query_engine.QueryEngineTool at 0x7f8d00e09af0>],
#  'Bloom app_v1.1_SRS.docx': [<llama_index.core.tools.query_engine.QueryEngineTool at 0x7f8d00bd7c40>,
#   <llama_index.core.tools.query_engine.QueryEngineTool at 0x7f8d00bd7640>]}

# %%
initial_tools = [t for paper in papers for t in paper_to_tools_dict[Path(paper).stem]]
print(str(initial_tools))
# Out:
# [<llama_index.core.tools.query_engine.QueryEngineTool object at 0x7f8d00e0e5e0>, <llama_index.core.tools.query_engine.QueryEngineTool object at 0x7f8cc382efa0>, <llama_index.core.tools.query_engine.QueryEngineTool object at 0x7f8d00e99d90>, <llama_index.core.tools.query_engine.QueryEngineTool object at 0x7f8d00e99e20>, <llama_index.core.tools.query_engine.QueryEngineTool object at 0x7f8d00bea370>, <llama_index.core.tools.query_engine.QueryEngineTool object at 0x7f8d00bea160>, <llama_index.core.tools.query_engine.QueryEngineTool object at 0x7f8d00e09d60>, <llama_index.core.tools.query_engine.QueryEngineTool object at 0x7f8d00e09af0>, <llama_index.core.tools.query_engine.QueryEngineTool object at 0x7f8d00bd7c40>, <llama_index.core.tools.query_engine.QueryEngineTool object at 0x7f8d00bd7640>]

# %%
len(initial_tools)
# Out:
# 10

# %%
# from llama_index.llms.openai import OpenAI
from llama_index.llms.ollama import Ollama
llm = Ollama(model="llama3.1:8b",request_timeout=3000.0)
# llm = OpenAI(model="gpt-4o-mini", temperature=0, api_key=OPENAI_API_KEY )

# %%
agent_worker = FunctionCallingAgentWorker.from_tools(
    initial_tools,
    llm=llm,
    verbose=True
)

agent = AgentRunner(agent_worker)
response = agent.query(
    "Who prepared these documents"
    
)

print(str(response))
# Out:
# Added user message to memory: Who prepared these documents
# === Calling Function ===
# Calling function: SRS__Tekdoc_summary_query_engine_tool with args: {"input": "Who prepared this document?"}
# === Function Output ===
# The document was prepared by Krishnapriya from Cubet Techno Labs PVT LTD.
# === Calling Function ===
# Calling function: AnaBot_Omang_plai__SRS_V1_docx_summary_query_engine_tool with args: {"input": "Who prepared this document?"}
# === Function Output ===
# The document was prepared by Aswathy A.
# === Calling Function ===
# Calling function: OPD_Booster-SRS_V3_0_summary_query_engine_tool with args: {"input": "Who prepared this document?"}
# === Function Output ===
# Sophy George prepared this document.
# === Calling Function ===
# Calling function: SRS__MyLeaseAudit_summary_query_engine_tool with args: {"input": "Who prepared this document?"}
# === Function Output ===
# The document was prepared by Krishnapriya.
# === Calling Function ===
# Calling function: Bloom_app_v1_1_SRS_docx_summary_query_engine_tool with args: {"input": "Who prepared this document?"}
# === Function Output ===
# The document was prepared by Rajeesh from Cubet Techno Labs PVT LTD.
# === LLM Response ===
# Here are the individuals who prepared the documents:
#
# 1. **SRS_Tekdoc**: Prepared by Krishnapriya from Cubet Techno Labs PVT LTD.
# 2. **AnaBot (Omang_plai) SRS V1**: Prepared by Aswathy A.
# 3. **OPD Booster-SRS V3.0**: Prepared by Sophy George.
# 4. **SRS MyLeaseAudit**: Prepared by Krishnapriya.
# 5. **Bloom app v1.1 SRS**: Prepared by Rajeesh from Cubet Techno Labs PVT LTD.
# Here are the individuals who prepared the documents:
#
# 1. **SRS_Tekdoc**: Prepared by Krishnapriya from Cubet Techno Labs PVT LTD.
# 2. **AnaBot (Omang_plai) SRS V1**: Prepared by Aswathy A.
# 3. **OPD Booster-SRS V3.0**: Prepared by Sophy George.
# 4. **SRS MyLeaseAudit**: Prepared by Krishnapriya.
# 5. **Bloom app v1.1 SRS**: Prepared by Rajeesh from Cubet Techno Labs PVT LTD.

# %%
def q_a_chatbot():
    print("Welcome to the document Q&A Chatbot!")
    print("Type 'exit' to quit.")
    
    while True:
        user_input = input("You: ")
        if user_input.lower() == 'exit':
            print("Chatbot: Goodbye!")
            break
        
        try:
            # Sending user's question to the agent
            response = agent.query(user_input)
            # Output the response from the agent
            print("Chatbot:", str(response))
        except Exception as e:
            print("Chatbot: Sorry, I couldn't process your request.")
            print(f"Error: {e}")

# Run the chatbot
q_a_chatbot()
# Out:
# Welcome to the Document Query Chatbot!
# Type 'exit' to quit.
# You:  Provide the names of the documents
# Added user message to memory: Provide the names of the documents
# === LLM Response ===
# The names of the documents are:
#
# 1. SRS_ Tekdoc
# 2. AnaBot(Omang_plai)_SRS_V1.docx
# 3. OPD Booster-SRS V3.0
# 4. SRS_ MyLeaseAudit
# 5. Bloom app_v1.1_SRS.docx
# Chatbot: The names of the documents are:
#
# 1. SRS_ Tekdoc
# 2. AnaBot(Omang_plai)_SRS_V1.docx
# 3. OPD Booster-SRS V3.0
# 4. SRS_ MyLeaseAudit
# 5. Bloom app_v1.1_SRS.docx
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[48], line 21
#      18             print(f"Error: {e}")
#      20 # Run the chatbot
# ---> 21 q_a_chatbot()
#
# Cell In[48], line 6, in q_a_chatbot()
#       3 print("Type 'exit' to quit.")
#       5 while True:
# ----> 6     user_input = input("You: ")
#       7     if user_input.lower() == 'exit':
#       8         print("Chatbot: Goodbye!")
#
# File ~/Desktop/cubet_assignment/jupenv/lib/python3.9/site-packages/ipykernel/kernelbase.py:1282, in Kernel.raw_input(self, prompt)
#    1280     msg = "raw_input was called, but this frontend does not support input requests."
#    1281     raise StdinNotImplementedError(msg)
# -> 1282 return self._input_request(
#    1283     str(prompt),
#    1284     self._parent_ident["shell"],
#    1285     self.get_parent("shell"),
#    1286     password=False,
#    1287 )
#
# File ~/Desktop/cubet_assignment/jupenv/lib/python3.9/site-packages/ipykernel/kernelbase.py:1325, in Kernel._input_request(self, prompt, ident, parent, password)
#    1322 except KeyboardInterrupt:
#    1323     # re-raise KeyboardInterrupt, to truncate traceback
#    1324     msg = "Interrupted by user"
# -> 1325     raise KeyboardInterrupt(msg) from None
#    1326 except Exception:
#    1327     self.log.warning("Invalid Message:", exc_info=True)
#
# KeyboardInterrupt: Interrupted by user

# %% [markdown]
# ## There is many different approach that we can make use to retrive the relevant documents as per the query to provide as input to the  LLMS.. I tried this approaced, wecan also make use of hybird  search approach, reranking of documents and multi query retrievel etx
